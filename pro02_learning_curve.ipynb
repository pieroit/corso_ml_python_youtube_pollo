# %%
from sklearn.datasets import load_digits

from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt

#!pip install yellowbrick 
from yellowbrick.model_selection import learning_curve

# %%
X, y = load_digits(return_X_y=True)

# %%
plt.imshow(X[0].reshape((8,8)))

# %%
model = MultinomialNB()

# %%
learning_curve(model, X, y, scoring='accuracy')
# Out:
# C:\Users\Piero\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# LearningCurve(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x000001F57DBC7B08>,
#               cv=None, exploit_incremental_learning=False, groups=None,
#               model=None, n_jobs=1, pre_dispatch='all', random_state=None,
#               scoring='accuracy', shuffle=False,
#               train_sizes=array([0.1  , 0.325, 0.55 , 0.775, 1.   ]))

# %%
models = [
    MultinomialNB(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(),
    DummyClassifier(),
]

# %%
for m in models:
    learning_curve(m, X, y)
# Out:
# C:\Users\Piero\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Piero\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Piero\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Piero\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

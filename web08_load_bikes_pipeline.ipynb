# %%
from joblib import load
import pandas as pd

# %%
df = pd.read_csv('hour.csv')
X = df.sample(10)

# %%
X
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 6718      6719  2011-10-12       4   0    10  12        0        3
# 6153      6154  2011-09-18       3   0     9  23        0        0
# 665        666  2011-01-31       1   0     1   1        0        1
# 9256      9257  2012-01-26       1   1     1  14        0        4
# 7168      7169  2011-10-31       4   0    10   7        0        1
# 704        705  2011-02-01       1   0     2  17        0        2
# 12668    12669  2012-06-17       2   1     6   1        0        0
# 13272    13273  2012-07-12       3   1     7   5        0        4
# 810        811  2011-02-06       1   0     2   5        0        0
# 13163    13164  2012-07-07       3   1     7  16        0        6
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 6718            1           3  0.54  0.5152  0.88     0.3284       9
# 6153            0           1  0.54  0.5152  0.68     0.1940      10
# ...

# %%
pipeline = load('bikes_pipeline.joblib')

# %%
pipeline.predict(X)
# Out:
# c:\users\piero\desktop\corso_ml_python_youtube_pollo\venv\lib\site-packages\sklearn\compose\_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# array([ 163.7230577 ,   79.9016453 , -104.23211634,  195.75817086,
#         165.67421425,  301.62050019,  109.01542036,   99.64875522,
#         -98.51438331,  469.85530495])

# %%
X['pred'] = pipeline.predict(X)
# Out:
# c:\users\piero\desktop\corso_ml_python_youtube_pollo\venv\lib\site-packages\sklearn\compose\_column_transformer.py:430: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)

# %%
X
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 6718      6719  2011-10-12       4   0    10  12        0        3
# 6153      6154  2011-09-18       3   0     9  23        0        0
# 665        666  2011-01-31       1   0     1   1        0        1
# 9256      9257  2012-01-26       1   1     1  14        0        4
# 7168      7169  2011-10-31       4   0    10   7        0        1
# 704        705  2011-02-01       1   0     2  17        0        2
# 12668    12669  2012-06-17       2   1     6   1        0        0
# 13272    13273  2012-07-12       3   1     7   5        0        4
# 810        811  2011-02-06       1   0     2   5        0        0
# 13163    13164  2012-07-07       3   1     7  16        0        6
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 6718            1           3  0.54  0.5152  0.88     0.3284       9
# 6153            0           1  0.54  0.5152  0.68     0.1940      10
# ...
